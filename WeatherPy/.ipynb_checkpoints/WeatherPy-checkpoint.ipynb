# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/jenienam/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/jenienam/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#urls
url = "http://api.openweathermap.org/data/2.5/weather?"

my_city = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat= []
Lng = []
Max_Temp = []
Wind_Speed = []

#counters
records = 1
sets = 1

# Loop through all the cities in our list
for city in cities:
    
    query_url = url + "appid=" + weather_api_key + "&q=" + city

    print("Processing Record %s of Set %s | %s" % (records, sets, city))
    
    try:
        response = requests.get(query_url).json()
        Cloudiness.append(response['clouds']['all'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Max_Temp.append(response['main']['temp_max'])
        Wind_Speed.append(response['wind']['speed']) 
       
        if records >= 49:
            records = 1
            sets += 1
            my_city.append(city)
        else:
            records += 1
            my_city.append(city)

    except:
        print("City not found. Skipping...")
        
print("(Data Retrieval Complete!!)---------------------")
# Out:
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | theologos
# City not found. Skipping...
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | tagusao
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | sao filipe
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | nurota
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | suratgarh
# Processing Record 13 of Set 1 | kahului
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | port lincoln
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 1 | kumluca
# Processing Record 19 of Set 1 | opuwo
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | mecca
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | carauari
# Processing Record 24 of Set 1 | demirci
# Processing Record 25 of Set 1 | tessalit
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | milkovo
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | beringovskiy
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | coffs harbour
# Processing Record 32 of Set 1 | assiniboia
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | westport
# Processing Record 37 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 1 | nalut
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | byron bay
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | belozerskoye
# Processing Record 42 of Set 1 | mponela
# Processing Record 43 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 1 | lavrentiya
# Processing Record 44 of Set 1 | kaitangata
# Processing Record 45 of Set 1 | sainte-marie
# Processing Record 46 of Set 1 | condado
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | ilulissat
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | cherskiy
# Processing Record 3 of Set 2 | mahebourg
# Processing Record 4 of Set 2 | pedasi
# Processing Record 5 of Set 2 | diu
# Processing Record 6 of Set 2 | komsomolskiy
# Processing Record 7 of Set 2 | den helder
# Processing Record 8 of Set 2 | bambous virieux
# Processing Record 9 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 9 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 2 | pingtung
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | abashiri
# Processing Record 12 of Set 2 | ongandjera
# Processing Record 13 of Set 2 | xining
# Processing Record 14 of Set 2 | port shepstone
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | mersing
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 2 | kodinsk
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | touros
# Processing Record 24 of Set 2 | roald
# Processing Record 25 of Set 2 | tabou
# Processing Record 26 of Set 2 | povenets
# Processing Record 27 of Set 2 | hasaki
# Processing Record 28 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | fortuna
# Processing Record 29 of Set 2 | pangnirtung
# Processing Record 30 of Set 2 | namibe
# Processing Record 31 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 2 | atar
# Processing Record 32 of Set 2 | te anau
# Processing Record 33 of Set 2 | brae
# Processing Record 34 of Set 2 | son la
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | kivsharivka
# Processing Record 38 of Set 2 | ayodhya
# Processing Record 39 of Set 2 | tommot
# Processing Record 40 of Set 2 | codrington
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | vardo
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | east london
# Processing Record 45 of Set 2 | sept-iles
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | ust-nera
# Processing Record 48 of Set 2 | bindura
# Processing Record 49 of Set 2 | torbay
# Processing Record 1 of Set 3 | cabo san lucas
# Processing Record 2 of Set 3 | korgen
# Processing Record 3 of Set 3 | ossora
# Processing Record 4 of Set 3 | wagar
# Processing Record 5 of Set 3 | porgera
# Processing Record 6 of Set 3 | kenai
# City not found. Skipping...
# Processing Record 6 of Set 3 | isangel
# Processing Record 7 of Set 3 | mpulungu
# Processing Record 8 of Set 3 | tilichiki
# Processing Record 9 of Set 3 | yatou
# Processing Record 10 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 3 | norman wells
# Processing Record 11 of Set 3 | corralillo
# Processing Record 12 of Set 3 | beruni
# City not found. Skipping...
# Processing Record 12 of Set 3 | baculin
# Processing Record 13 of Set 3 | mafeteng
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | severo-kurilsk
# Processing Record 16 of Set 3 | hoquiam
# Processing Record 17 of Set 3 | cidreira
# Processing Record 18 of Set 3 | tulun
# Processing Record 19 of Set 3 | mus
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | los algarrobos
# Processing Record 22 of Set 3 | arman
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | alexandria
# Processing Record 25 of Set 3 | vedaranniyam
# City not found. Skipping...
# Processing Record 25 of Set 3 | tuatapere
# Processing Record 26 of Set 3 | salihorsk
# Processing Record 27 of Set 3 | enshi
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 3 | mogwase
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | kosa
# Processing Record 31 of Set 3 | clyde river
# Processing Record 32 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | victoria
# Processing Record 34 of Set 3 | tiznit
# Processing Record 35 of Set 3 | bardiyah
# Processing Record 36 of Set 3 | da lat
# Processing Record 37 of Set 3 | hithadhoo
# Processing Record 38 of Set 3 | klyuchi
# Processing Record 39 of Set 3 | talara
# Processing Record 40 of Set 3 | port elizabeth
# Processing Record 41 of Set 3 | jiuquan
# Processing Record 42 of Set 3 | iralaya
# Processing Record 43 of Set 3 | sidrolandia
# Processing Record 44 of Set 3 | pecos
# Processing Record 45 of Set 3 | ponta do sol
# Processing Record 46 of Set 3 | carutapera
# Processing Record 47 of Set 3 | garni
# Processing Record 48 of Set 3 | cayenne
# Processing Record 49 of Set 3 | banda aceh
# Processing Record 1 of Set 4 | kibre mengist
# Processing Record 2 of Set 4 | barao de melgaco
# Processing Record 3 of Set 4 | lata
# Processing Record 4 of Set 4 | nome
# Processing Record 5 of Set 4 | fairbanks
# Processing Record 6 of Set 4 | acin
# City not found. Skipping...
# Processing Record 6 of Set 4 | talcahuano
# Processing Record 7 of Set 4 | murray bridge
# Processing Record 8 of Set 4 | chuy
# Processing Record 9 of Set 4 | masinigudi
# Processing Record 10 of Set 4 | steyregg
# Processing Record 11 of Set 4 | muroto
# Processing Record 12 of Set 4 | oranjemund
# Processing Record 13 of Set 4 | srednekolymsk
# Processing Record 14 of Set 4 | ca mau
# Processing Record 15 of Set 4 | kysyl-syr
# Processing Record 16 of Set 4 | jishou
# Processing Record 17 of Set 4 | mitsamiouli
# Processing Record 18 of Set 4 | rengo
# Processing Record 19 of Set 4 | tomatlan
# Processing Record 20 of Set 4 | ulladulla
# Processing Record 21 of Set 4 | namangan
# Processing Record 22 of Set 4 | valparaiso
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 4 | sao felix do xingu
# Processing Record 24 of Set 4 | havre
# Processing Record 25 of Set 4 | huilong
# Processing Record 26 of Set 4 | talnakh
# Processing Record 27 of Set 4 | ahipara
# Processing Record 28 of Set 4 | thunder bay
# Processing Record 29 of Set 4 | berezovyy
# Processing Record 30 of Set 4 | lodwar
# Processing Record 31 of Set 4 | samarai
# Processing Record 32 of Set 4 | dangriga
# Processing Record 33 of Set 4 | katakwi
# Processing Record 34 of Set 4 | dingli
# Processing Record 35 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 35 of Set 4 | reinosa
# Processing Record 36 of Set 4 | karpathos
# Processing Record 37 of Set 4 | shaunavon
# Processing Record 38 of Set 4 | kamaishi
# Processing Record 39 of Set 4 | colborne
# Processing Record 40 of Set 4 | katsuura
# Processing Record 41 of Set 4 | mulki
# Processing Record 42 of Set 4 | kindu
# Processing Record 43 of Set 4 | cockburn town
# Processing Record 44 of Set 4 | san cristobal
# Processing Record 45 of Set 4 | klaksvik
# Processing Record 46 of Set 4 | adrar
# Processing Record 47 of Set 4 | port hardy
# Processing Record 48 of Set 4 | vaniyambadi
# Processing Record 49 of Set 4 | homer
# Processing Record 1 of Set 5 | ganzhou
# Processing Record 2 of Set 5 | sumkino
# Processing Record 3 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 5 | amapa
# Processing Record 4 of Set 5 | omboue
# Processing Record 5 of Set 5 | mangrol
# Processing Record 6 of Set 5 | madang
# Processing Record 7 of Set 5 | faanui
# Processing Record 8 of Set 5 | aasiaat
# Processing Record 9 of Set 5 | balikpapan
# Processing Record 10 of Set 5 | vilcun
# Processing Record 11 of Set 5 | longyearbyen
# Processing Record 12 of Set 5 | kuusamo
# Processing Record 13 of Set 5 | kaeo
# Processing Record 14 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 5 | mount isa
# Processing Record 15 of Set 5 | khatanga
# Processing Record 16 of Set 5 | san policarpo
# Processing Record 17 of Set 5 | kununurra
# Processing Record 18 of Set 5 | tautira
# Processing Record 19 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 5 | babstovo
# Processing Record 20 of Set 5 | nata
# Processing Record 21 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 5 | antalaha
# Processing Record 22 of Set 5 | ponnampet
# Processing Record 23 of Set 5 | campbell river
# Processing Record 24 of Set 5 | ixtapa
# Processing Record 25 of Set 5 | bairiki
# Processing Record 26 of Set 5 | mayo
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | bathsheba
# Processing Record 29 of Set 5 | leningradskiy
# Processing Record 30 of Set 5 | lagoa
# Processing Record 31 of Set 5 | khagrachari
# City not found. Skipping...
# Processing Record 31 of Set 5 | yinchuan
# Processing Record 32 of Set 5 | salalah
# Processing Record 33 of Set 5 | cobija
# Processing Record 34 of Set 5 | babanka
# Processing Record 35 of Set 5 | hamilton
# Processing Record 36 of Set 5 | vrangel
# Processing Record 37 of Set 5 | okhotsk
# Processing Record 38 of Set 5 | tazovskiy
# Processing Record 39 of Set 5 | yar-sale
# Processing Record 40 of Set 5 | puerto escondido
# Processing Record 41 of Set 5 | raudeberg
# Processing Record 42 of Set 5 | inverell
# Processing Record 43 of Set 5 | jumla
# Processing Record 44 of Set 5 | findhorn
# Processing Record 45 of Set 5 | alta floresta
# Processing Record 46 of Set 5 | manbij
# Processing Record 47 of Set 5 | akdepe
# Processing Record 48 of Set 5 | salto
# Processing Record 49 of Set 5 | mwinilunga
# Processing Record 1 of Set 6 | vila velha
# Processing Record 2 of Set 6 | waipawa
# Processing Record 3 of Set 6 | thompson
# Processing Record 4 of Set 6 | kavieng
# Processing Record 5 of Set 6 | constitucion
# Processing Record 6 of Set 6 | carnarvon
# Processing Record 7 of Set 6 | harindanga
# Processing Record 8 of Set 6 | acapulco
# Processing Record 9 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 6 | geraldton
# Processing Record 10 of Set 6 | challans
# Processing Record 11 of Set 6 | tupik
# Processing Record 12 of Set 6 | lazaro cardenas
# Processing Record 13 of Set 6 | fukue
# Processing Record 14 of Set 6 | brejinho
# Processing Record 15 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 6 | pacific grove
# Processing Record 16 of Set 6 | gisors
# Processing Record 17 of Set 6 | seydi
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | rocha
# Processing Record 20 of Set 6 | esfarayen
# Processing Record 21 of Set 6 | vuktyl
# Processing Record 22 of Set 6 | kaseda
# Processing Record 23 of Set 6 | iqaluit
# Processing Record 24 of Set 6 | linapacan
# City not found. Skipping...
# Processing Record 24 of Set 6 | ostersund
# Processing Record 25 of Set 6 | nishihara
# Processing Record 26 of Set 6 | hofn
# Processing Record 27 of Set 6 | gerash
# Processing Record 28 of Set 6 | jaciara
# Processing Record 29 of Set 6 | grindavik
# Processing Record 30 of Set 6 | ayagoz
# Processing Record 31 of Set 6 | yulara
# Processing Record 32 of Set 6 | pimentel
# Processing Record 33 of Set 6 | slave lake
# Processing Record 34 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 6 | warangal
# Processing Record 35 of Set 6 | saint-joseph
# Processing Record 36 of Set 6 | maracanau
# Processing Record 37 of Set 6 | mehamn
# Processing Record 38 of Set 6 | saint anthony
# Processing Record 39 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 6 | nerchinsk
# Processing Record 40 of Set 6 | alamosa
# Processing Record 41 of Set 6 | luwuk
# Processing Record 42 of Set 6 | harper
# Processing Record 43 of Set 6 | svetlyy
# Processing Record 44 of Set 6 | union
# Processing Record 45 of Set 6 | lerik
# Processing Record 46 of Set 6 | saint-georges
# Processing Record 47 of Set 6 | zermatt
# Processing Record 48 of Set 6 | kavaratti
# City not found. Skipping...
# Processing Record 48 of Set 6 | zanjan
# Processing Record 49 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 6 | ketchikan
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | kaohsiung
# Processing Record 3 of Set 7 | meulaboh
# Processing Record 4 of Set 7 | svetlogorsk
# Processing Record 5 of Set 7 | balykshi
# City not found. Skipping...
# Processing Record 5 of Set 7 | polewali
# Processing Record 6 of Set 7 | husavik
# Processing Record 7 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 7 | neryungri
# Processing Record 8 of Set 7 | gimli
# Processing Record 9 of Set 7 | padang
# Processing Record 10 of Set 7 | champerico
# Processing Record 11 of Set 7 | chaihe
# Processing Record 12 of Set 7 | olga
# Processing Record 13 of Set 7 | nhulunbuy
# Processing Record 14 of Set 7 | karasjok
# Processing Record 15 of Set 7 | caravelas
# Processing Record 16 of Set 7 | progreso
# Processing Record 17 of Set 7 | melito di porto salvo
# Processing Record 18 of Set 7 | ramhormoz
# Processing Record 19 of Set 7 | maniitsoq
# Processing Record 20 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 7 | santa rosa
# Processing Record 21 of Set 7 | khasan
# Processing Record 22 of Set 7 | sibolga
# Processing Record 23 of Set 7 | san carlos
# Processing Record 24 of Set 7 | nzega
# Processing Record 25 of Set 7 | churapcha
# Processing Record 26 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 7 | esperance
# Processing Record 27 of Set 7 | grand gaube
# Processing Record 28 of Set 7 | pombas
# Processing Record 29 of Set 7 | guerrero negro
# Processing Record 30 of Set 7 | pisco
# Processing Record 31 of Set 7 | campbellsville
# Processing Record 32 of Set 7 | gamba
# Processing Record 33 of Set 7 | kabanjahe
# Processing Record 34 of Set 7 | narsaq
# Processing Record 35 of Set 7 | gorontalo
# Processing Record 36 of Set 7 | elko
# Processing Record 37 of Set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 37 of Set 7 | matara
# Processing Record 38 of Set 7 | cordoba
# Processing Record 39 of Set 7 | colac
# Processing Record 40 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 7 | rawson
# Processing Record 41 of Set 7 | port blair
# Processing Record 42 of Set 7 | gaurnadi
# Processing Record 43 of Set 7 | lulea
# Processing Record 44 of Set 7 | naze
# Processing Record 45 of Set 7 | kungurtug
# Processing Record 46 of Set 7 | lorengau
# Processing Record 47 of Set 7 | igdir
# Processing Record 48 of Set 7 | coihaique
# Processing Record 49 of Set 7 | baruun-urt
# Processing Record 1 of Set 8 | alvares machado
# Processing Record 2 of Set 8 | tombouctou
# Processing Record 3 of Set 8 | zhongshan
# Processing Record 4 of Set 8 | tual
# Processing Record 5 of Set 8 | lufkin
# Processing Record 6 of Set 8 | sukhumi
# Processing Record 7 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 8 | hovd
# Processing Record 8 of Set 8 | sicamous
# Processing Record 9 of Set 8 | upernavik
# Processing Record 10 of Set 8 | rio gallegos
# Processing Record 11 of Set 8 | luderitz
# Processing Record 12 of Set 8 | lasa
# Processing Record 13 of Set 8 | camacha
# Processing Record 14 of Set 8 | ordu
# Processing Record 15 of Set 8 | kieta
# Processing Record 16 of Set 8 | alugan
# Processing Record 17 of Set 8 | nikolskoye
# Processing Record 18 of Set 8 | bosaso
# Processing Record 19 of Set 8 | kyzyl-suu
# Processing Record 20 of Set 8 | limbe
# Processing Record 21 of Set 8 | santa cruz cabralia
# Processing Record 22 of Set 8 | asau
# Processing Record 23 of Set 8 | swakopmund
# Processing Record 24 of Set 8 | diamantino
# Processing Record 25 of Set 8 | soyo
# Processing Record 26 of Set 8 | khandyga
# Processing Record 27 of Set 8 | haimen
# Processing Record 28 of Set 8 | flin flon
# Processing Record 29 of Set 8 | vitimskiy
# City not found. Skipping...
# Processing Record 29 of Set 8 | namatanai
# Processing Record 30 of Set 8 | maningrida
# Processing Record 31 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 8 | kargasok
# Processing Record 32 of Set 8 | bonfim
# Processing Record 33 of Set 8 | auki
# Processing Record 34 of Set 8 | poyarkovo
# Processing Record 35 of Set 8 | egvekinot
# Processing Record 36 of Set 8 | broome
# Processing Record 37 of Set 8 | necochea
# Processing Record 38 of Set 8 | gboko
# Processing Record 39 of Set 8 | puerto colombia
# Processing Record 40 of Set 8 | saint-avold
# Processing Record 41 of Set 8 | miandoab
# Processing Record 42 of Set 8 | la rochelle
# Processing Record 43 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 8 | rio grande
# Processing Record 45 of Set 8 | sola
# Processing Record 46 of Set 8 | kutum
# Processing Record 47 of Set 8 | alofi
# Processing Record 48 of Set 8 | severobaykalsk
# Processing Record 49 of Set 8 | koutsouras
# Processing Record 1 of Set 9 | morgan city
# Processing Record 2 of Set 9 | arlit
# Processing Record 3 of Set 9 | mogadishu
# Processing Record 4 of Set 9 | kawalu
# Processing Record 5 of Set 9 | dong hoi
# Processing Record 6 of Set 9 | yerbogachen
# Processing Record 7 of Set 9 | wilmington
# Processing Record 8 of Set 9 | margate
# Processing Record 9 of Set 9 | andros town
# Processing Record 10 of Set 9 | russell
# Processing Record 11 of Set 9 | mashhad
# Processing Record 12 of Set 9 | trabzon
# Processing Record 13 of Set 9 | saldanha
# Processing Record 14 of Set 9 | soure
# Processing Record 15 of Set 9 | paamiut
# Processing Record 16 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 16 of Set 9 | morondava
# Processing Record 17 of Set 9 | luganville
# Processing Record 18 of Set 9 | bubaque
# Processing Record 19 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 19 of Set 9 | salinopolis
# Processing Record 20 of Set 9 | aljezur
# Processing Record 21 of Set 9 | tocopilla
# Processing Record 22 of Set 9 | sinnamary
# Processing Record 23 of Set 9 | mayya
# Processing Record 24 of Set 9 | soligalich
# Processing Record 25 of Set 9 | manggar
# Processing Record 26 of Set 9 | kampot
# Processing Record 27 of Set 9 | itarema
# Processing Record 28 of Set 9 | roma
# Processing Record 29 of Set 9 | dingzhou
# Processing Record 30 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 30 of Set 9 | bowen
# Processing Record 31 of Set 9 | howard springs
# Processing Record 32 of Set 9 | key largo
# Processing Record 33 of Set 9 | vilhena
# Processing Record 34 of Set 9 | najran
# Processing Record 35 of Set 9 | coquimbo
# Processing Record 36 of Set 9 | bohdan
# Processing Record 37 of Set 9 | winsum
# Processing Record 38 of Set 9 | jieshi
# Processing Record 39 of Set 9 | chino valley
# Processing Record 40 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 40 of Set 9 | udachnyy
# Processing Record 41 of Set 9 | airai
# Processing Record 42 of Set 9 | bac lieu
# Processing Record 43 of Set 9 | buchanan
# Processing Record 44 of Set 9 | ishigaki
# Processing Record 45 of Set 9 | mount gambier
# Processing Record 46 of Set 9 | kjollefjord
# Processing Record 47 of Set 9 | bonnyville
# Processing Record 48 of Set 9 | nanortalik
# Processing Record 49 of Set 9 | vila
# Processing Record 1 of Set 10 | bilibino
# Processing Record 2 of Set 10 | yenagoa
# Processing Record 3 of Set 10 | kemijarvi
# Processing Record 4 of Set 10 | cienfuegos
# Processing Record 5 of Set 10 | wanning
# Processing Record 6 of Set 10 | marshall
# Processing Record 7 of Set 10 | vestmannaeyjar
# Processing Record 8 of Set 10 | witney
# Processing Record 9 of Set 10 | chipinge
# Processing Record 10 of Set 10 | luena
# Processing Record 11 of Set 10 | qiongshan
# Processing Record 12 of Set 10 | viedma
# Processing Record 13 of Set 10 | requena
# Processing Record 14 of Set 10 | kalmunai
# Processing Record 15 of Set 10 | zhanaozen
# Processing Record 16 of Set 10 | zhezkazgan
# Processing Record 17 of Set 10 | huarmey
# Processing Record 18 of Set 10 | buala
# Processing Record 19 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 19 of Set 10 | morrope
# Processing Record 20 of Set 10 | santa barbara
# Processing Record 21 of Set 10 | kon tum
# Processing Record 22 of Set 10 | mbanza-ngungu
# Processing Record 23 of Set 10 | bengkulu
# Processing Record 24 of Set 10 | chumikan
# Processing Record 25 of Set 10 | kidal
# Processing Record 26 of Set 10 | portland
# Processing Record 27 of Set 10 | languyan
# Processing Record 28 of Set 10 | carndonagh
# Processing Record 29 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 29 of Set 10 | lufilufi
# Processing Record 30 of Set 10 | battonya
# Processing Record 31 of Set 10 | leh
# Processing Record 32 of Set 10 | sakakah
# Processing Record 33 of Set 10 | san carlos de bariloche
# Processing Record 34 of Set 10 | carballo
# Processing Record 35 of Set 10 | maarianhamina
# Processing Record 36 of Set 10 | sisimiut
# Processing Record 37 of Set 10 | bealanana
# Processing Record 38 of Set 10 | sembe
# Processing Record 39 of Set 10 | maridi
# Processing Record 40 of Set 10 | avera
# Processing Record 41 of Set 10 | sitka
# Processing Record 42 of Set 10 | leo
# Processing Record 43 of Set 10 | rafraf
# Processing Record 44 of Set 10 | mezen
# Processing Record 45 of Set 10 | zeya
# Processing Record 46 of Set 10 | saint-francois
# Processing Record 47 of Set 10 | mackay
# Processing Record 48 of Set 10 | porbandar
# Processing Record 49 of Set 10 | san patricio
# Processing Record 1 of Set 11 | takoradi
# Processing Record 2 of Set 11 | kuah
# Processing Record 3 of Set 11 | tonantins
# Processing Record 4 of Set 11 | kizema
# City not found. Skipping...
# Processing Record 4 of Set 11 | voyvozh
# Processing Record 5 of Set 11 | point fortin
# Processing Record 6 of Set 11 | zaraza
# Processing Record 7 of Set 11 | hirara
# Processing Record 8 of Set 11 | camacari
# Processing Record 9 of Set 11 | san nicolas
# Processing Record 10 of Set 11 | dioknisi
# Processing Record 11 of Set 11 | san vicente
# Processing Record 12 of Set 11 | biak
# Processing Record 13 of Set 11 | tsabong
# Processing Record 14 of Set 11 | conde
# Processing Record 15 of Set 11 | alfatar
# Processing Record 16 of Set 11 | sovetskiy
# Processing Record 17 of Set 11 | illapel
# Processing Record 18 of Set 11 | santa maria
# Processing Record 19 of Set 11 | marienburg
# Processing Record 20 of Set 11 | nantucket
# Processing Record 21 of Set 11 | elizabeth city
# Processing Record 22 of Set 11 | deputatskiy
# Processing Record 23 of Set 11 | comodoro rivadavia
# Processing Record 24 of Set 11 | aripuana
# Processing Record 25 of Set 11 | druzhba
# Processing Record 26 of Set 11 | aykhal
# Processing Record 27 of Set 11 | christchurch
# Processing Record 28 of Set 11 | muros
# Processing Record 29 of Set 11 | fallon
# Processing Record 30 of Set 11 | pundaguitan
# Processing Record 31 of Set 11 | yarega
# Processing Record 32 of Set 11 | nokaneng
# Processing Record 33 of Set 11 | marawi
# Processing Record 34 of Set 11 | palmerston north
# Processing Record 35 of Set 11 | mindelo
# Processing Record 36 of Set 11 | hami
# Processing Record 37 of Set 11 | ahuimanu
# Processing Record 38 of Set 11 | qaqortoq
# Processing Record 39 of Set 11 | nouakchott
# Processing Record 40 of Set 11 | ancud
# Processing Record 41 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 11 | sao jose da coroa grande
# Processing Record 42 of Set 11 | tyshkivka
# Processing Record 43 of Set 11 | maiduguri
# Processing Record 44 of Set 11 | queanbeyan
# Processing Record 45 of Set 11 | santo tomas
# Processing Record 46 of Set 11 | sur
# Processing Record 47 of Set 11 | darnah
# Processing Record 48 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 11 | katangli
# Processing Record 49 of Set 11 | kishtwar
# Processing Record 1 of Set 12 | tutrakan
# Processing Record 2 of Set 12 | vestmanna
# Processing Record 3 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 12 | cairns
# Processing Record 4 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 12 | college
# Processing Record 5 of Set 12 | siocon
# Processing Record 6 of Set 12 | nadym
# Processing Record 7 of Set 12 | gizo
# Processing Record 8 of Set 12 | san jose
# Processing Record 9 of Set 12 | fonte boa
# Processing Record 10 of Set 12 | guymon
# Processing Record 11 of Set 12 | iskateley
# Processing Record 12 of Set 12 | perbaungan
# Processing Record 13 of Set 12 | raboso
# Processing Record 14 of Set 12 | shingu
# Processing Record 15 of Set 12 | paoua
# Processing Record 16 of Set 12 | anadyr
# Processing Record 17 of Set 12 | houma
# Processing Record 18 of Set 12 | alice springs
# Processing Record 19 of Set 12 | urengoy
# Processing Record 20 of Set 12 | las tunas
# Processing Record 21 of Set 12 | nizhniy kuranakh
# Processing Record 22 of Set 12 | halmstad
# Processing Record 23 of Set 12 | rognan
# Processing Record 24 of Set 12 | merauke
# Processing Record 25 of Set 12 | kirakira
# (Data Retrieval Complete!!)---------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data = {"City": cities,
    "Cloudiness": Cloudiness,
    "Country": Country,
    "Date": Date,
    "Humidity": Humidity,
    "Lat": Lat,
    "Lng": Lng,
    "Max Temp": Max_Temp,
    "Wind Speed": Wind_Speed}

data1 = pd.DataFrame.from_dict(data, orient='index')
data_df = data1.transpose()
data_df.dropna()
data_df
data_df.to_csv(output_data_filse, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-72ea0485a1b5> in <module>
#      13 data_df.dropna()
#      14 data_df
# ---> 15 data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/cities.csv'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
